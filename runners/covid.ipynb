# %%
from covid.common import SparkSessionService

# %%
workspace_path = "COVID-DATABRICKS"
database_path = f"/{workspace_path}/.data"
spark_session_service = SparkSessionService()
spark = spark_session_service.get_spark_session()
# Out:
# :: loading settings :: url = jar:file:/opt/conda/envs/pyspark/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-47341d83-763d-456d-a660-790876eb6873;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 225ms :: artifacts dl 13ms
# 	:: modules in use:
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-47341d83-763d-456d-a660-790876eb6873
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/10ms)
# 25/11/15 12:43:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
from covid.bronze import ingest_raw_files

landing_path = f"{database_path}/raw/HIST_PAINEL_COVIDBR_2020_Parte1_05set2025.csv"
bronze_path = f"{database_path}/bronze/covid"

ingest_raw_files(spark, landing_path, bronze_path)
# Out:
# 25/11/15 12:43:38 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
covid_df = spark.read.format("delta").load(bronze_path)
covid_df.show()
# Out:
# +------+------+---------+-----+------+--------------+---------------+----------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# |regiao|estado|municipio|coduf|codmun|codRegiaoSaude|nomeRegiaoSaude|      data|semanaEpi|populacaoTCU2019|casosAcumulado|casosNovos|obitosAcumulado|obitosNovos|Recuperadosnovos|emAcompanhamentoNovos|interior/metropolitana|
# +------+------+---------+-----+------+--------------+---------------+----------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-25|        9|       210147125|             0|         0|              0|          0|               0|                    0|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-26|        9|       210147125|             1|         1|              0|          0|               1|                    0|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-27|        9|       210147125|             1|         0|              0|          0|               1|                    0|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-28|        9|       210147125|             1|         0|              0|          0|               0|                    1|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-02-29|        9|       210147125|             2|         1|              0|          0|               1|                    1|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-01|       10|       210147125|             2|         0|              0|          0|               1|                    1|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-02|       10|       210147125|             2|         0|              0|          0|               0|                    2|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-03|       10|       210147125|             2|         0|              0|          0|               0|                    2|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-04|       10|       210147125|             3|         1|              0|          0|               1|                    2|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-05|       10|       210147125|             7|         4|              0|          0|               4|                    3|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-06|       10|       210147125|            13|         6|              0|          0|               6|                    7|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-07|       10|       210147125|            19|         6|              0|          0|               7|                   12|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-08|       11|       210147125|            25|         6|              0|          0|               6|                   19|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-09|       11|       210147125|            25|         0|              0|          0|               1|                   24|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-10|       11|       210147125|            34|         9|              0|          0|               6|                   28|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-11|       11|       210147125|            52|        18|              0|          0|              16|                   36|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-12|       11|       210147125|            77|        25|              0|          0|              23|                   54|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-13|       11|       210147125|            98|        21|              0|          0|              24|                   74|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-14|       11|       210147125|           121|        23|              0|          0|              22|                   99|                  null|
# |Brasil|  null|     null|   76|  null|          null|           null|2020-03-15|       12|       210147125|           200|        79|              0|          0|              62|                  138|                  null|
# +------+------+---------+-----+------+--------------+---------------+----------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+
# only showing top 20 rows
